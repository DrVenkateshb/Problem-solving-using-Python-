# %% [markdown]
# ### Introduction to python
# 1. introduction
# 2. datatypes
# 3. expression

# %%
a=20
b=6
a+b
# Out:
# 26

# %%
a = 10
b = 20

print('The sum of', a, 'and', b, 'is', a + b)
# Out:
# The sum of 10 and 20 is 30

# %%
a=int(input('Enter an integer: '))
b=int(input('Enter another integer: '))
print('The sum of', a, 'and', b, 'is', a + b)
# Out:
# The sum of 23 and 30 is 53
